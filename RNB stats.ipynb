# %%
# Libraries

import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100)

import matplotlib.pyplot as plt

# Import/export

import urllib.request
import re
import csv

# %%
# Variables

folder_name = 'C:/Users/j.petit/Documents/Python/0000_donnees/export/via API/'
file_name = "equipement.csv"
file_path = folder_name + file_name
export_dc = "https://equipements.sports.gouv.fr/api/explore/v2.1/catalog/datasets/data-es/exports/csv"


# Mise à jour du fichier dans le dossier
#urllib.request.urlretrieve(export_dc, file_path)


# Transformation du fichier du dossier en dataframe

print("Import de df")
df = pd.read_csv(file_path, sep=";", low_memory=False, dtype="str")
print(len(df))
df.sample(2)
# Out:
# Import de df
# 333038
#           equip_numero inst_numero inst_enqu_date  \
# 9779    E001I682390001  I682390001     2025-03-31
# 121520  E004I452340078  I452340078     2025-03-31
#
#                                   inst_nom inst_siret         inst_adresse  \
# 9779    Circuits de randonnées circulaires        NaN                  NaN
# 121520     STADE ORLEANS LA SOURCE ET CRJS        NaN  7 Rue de Beaumarché
#
#        inst_cp   new_name new_code inst_part_type_filter inst_uai  \
# 9779     68290  Oberbruck    68239                   NaN      NaN
# 121520   45000    Orléans    45234      Complexe sportif      NaN
#
#         inst_acc_handi_type inst_trans_type  \
# 9779                    NaN             NaN
# 121520  ["Handicap moteur"]             NaN
#
#                                                  inst_obs inst_date_etat  \
# 9779                                                  NaN     2024-06-21
# 121520  Centre de Préparation aux Jeux (CPJ) (Stade de...     2024-02-12
#
#        inst_date_creation inst_hs_bool  epci_code dep_code    dep_nom  \
# 9779           2006-10-01        false  246800676       68  Haut-Rhin
# 121520         2005-08-02        false  244500468       45     Loiret
#
#        reg_code              reg_nom  \
# 9779         44            Grand Est
# 121520       24  Centre-Val de Loire
#
#                                              epci_nom code_bdv  \
# 9779    CC de la Vallée de la Doller et du Soultzbach    68201
# 121520                              Orléans Métropole    45234
#
#                      lib_bdv arr_code          arr_name dens_niveau  \
# 9779    Masevaux-Niederbruck      686  Thann-Guebwiller           5
# 121520               Orléans      452           Orléans           1
#
#                       dens_lib dep_code_filled                   aca_nom  \
# 9779             Bourgs ruraux              68    Académie de Strasbourg
# 121520  Grands centres urbains              45  Académie d'Orléans-Tours
#
#                         zrr_simp                              equip_nom  \
# 9779    NC - Commune non classée  Tour du grand Neuweïer - Anneau rouge
# 121520  NC - Commune non classée      Terrain de foot (gazonné poussin)
#
#             equip_type_name             equip_coordonnees equip_prop_nom  \
# 9779    Boucle de randonnée             47.80766, 6.93945            NaN
# 121520  Terrain de football  47.8436493572, 1.94441028183         Mairie
#
#        equip_prop_type equip_propsec_type equip_gest_type equip_cogest_type  \
# 9779           Commune                NaN  Association(s)               NaN
# 121520         Commune                NaN         Commune               NaN
#
#        equip_dsp equip_ouv_public_bool equip_erp_type equip_erp_cat  \
# 9779       false                 false            NaN           NaN
# 121520     false                  true    ["PA", "X"]             5
#
#        equip_homo_date equip_homo_periode equip_service_date  \
# 9779               NaN                NaN               1999
# 121520             NaN                NaN               1976
#
#        equip_service_periode equip_travaux_date equip_travaux_periode  \
# 9779               1995-2004                NaN                   NaN
# 121520             1975-1984                NaN                   NaN
#
#        equip_travaux_type equip_energie          equip_nature  \
# 9779                  NaN           NaN  Site naturel aménagé
# 121520                NaN           NaN             Découvert
#
#                 equip_sol equip_long equip_larg equip_haut equip_surf  \
# 9779    Surface naturelle     3000.0        NaN        NaN        NaN
# 121520      Gazon naturel       70.0       41.0        NaN     2450.0
#
#        equip_eclair equip_trib_nb equip_vest_sport equip_vest_ens  \
# 9779          false             0                0              0
# 121520         true             0               12              2
#
#        equip_douche equip_sanit  \
# 9779          false       false
# 121520         true        true
#
#                                            equip_loc_type equip_conf_type  \
# 9779                                                  NaN             NaN
# 121520  ["Reception/accueil", "Bureau(x) club(s)", "Bu...             NaN
#
#        equip_acces_handi_mobilite equip_acces_handi_sensoriel  \
# 9779                          NaN                         NaN
# 121520      Sanitaires,Vestiaires                  Sanitaires
#
#        equip_pdesi_pdipr equip_bassin_long equip_bassin_larg  \
# 9779                 NaN               NaN               NaN
# 121520               NaN               NaN               NaN
#
#        equip_bassin_surf equip_bassin_min equip_bassin_max equip_piste_long  \
# 9779                 NaN              NaN              NaN              NaN
# 121520               NaN              NaN              NaN              NaN
#
#        equip_sae_haut equip_sae_surf equip_sae_couloir equip_pasdetir  \
# 9779              NaN            NaN               NaN            NaN
# 121520            NaN            NaN               NaN            NaN
#
#        equip_url                                  equip_utilisateur  \
# 9779         NaN  ["Individuel(s),famille(s)", "Clubs sportifs,c...
# 121520       NaN  ["Clubs sportifs,comités,ligues,fédérations", ...
#
#        equip_acc_libre equip_saison equip_obs  \
# 9779              true        false       NaN
# 121520           false        false       NaN
#
#                          equip_type_famille equip_type_code equip_rnb  \
# 9779    Divers équipements Sports de nature            3012       NaN
# 121520               Terrain de grands jeux            2802       NaN
#
#        inst_acc_handi_bool inst_trans_bool inst_part_bool equip_loc_bool  \
# 9779                 false           false          false          false
# 121520                true           false           true           true
#
#        equip_pmr_vest equip_pmr_acc equip_pmr_aire equip_pmr_chem  \
# 9779            false         false          false          false
# 121520           true         false          false          false
#
#        equip_pmr_douche equip_pmr_sanit equip_pmr_trib equip_pshs_aire  \
# 9779              false           false          false           false
# 121520            false            true          false           false
#
#        equip_pshs_chem equip_pshs_sanit equip_pshs_sign equip_pshs_trib  \
# 9779             false            false           false           false
# 121520           false             true           false           false
#
#        equip_pshs_vest        equip_x        equip_y        inst_part_type  \
# 9779             false       47.80766        6.93945                   NaN
# 121520           false  47.8436493572  1.94441028183  ["Complexe sportif"]
#
#        equip_qpv equip_qpv_200m    categorie
# 9779         NaN            NaN          NaN
# 121520       NaN            NaN  structurant

# %%
# Import des données DPE
# https://data.ademe.fr/datasets/dpe01tertiaire/full?_d_j9ol0fwjqckyf49vr29nknbu_secteur_activite_eq=X%20%3A%20%C3%89tablissements%20sportifs%20couverts

file_dpe = "dpe01tertiaire.xlsx"

print("Import de df_dpe")
df_dpe = pd.read_excel(file_dpe)
print(len(df_dpe))
df_dpe.sample(2)
# Out:
# Import de df_dpe
# 1897
#          numero_dpe date_derniere_modification_dpe date_visite_diagnostiqueur  \
# 257   2318T3295906Z                     2024-12-30                 2023-10-01
# 1111  2395T3515523T                     2023-10-26                 2023-10-03
#
#      date_etablissement_dpe date_reception_dpe date_fin_validite_dpe  \
# 257              2023-10-01         2023-10-02            2033-09-30
# 1111             2023-10-17         2023-10-18            2033-10-16
#
#      numero_dpe_remplace  numero_dpe_immeuble_associe        id_rnb  \
# 257                  NaN                          NaN  K7PDVJMJRFVB
# 1111                 NaN                          NaN           NaN
#
#      provenance_id_rnb numero_immatriculation_copropriete  \
# 257        Reprise RNB                                NaN
# 1111               NaN                                NaN
#
#                      modele_dpe  version_dpe            methode_dpe  \
# 257   DPE 2006 tertiaire et ERP          2.3   dpe tertiaire vierge
# 1111  DPE 2006 tertiaire et ERP          2.3  dpe tertiaire facture
#
#        categorie_erp                      secteur_activite etiquette_dpe  \
# 257   5ème Catégorie  X : Établissements sportifs couverts           NaN
# 1111  5ème Catégorie  X : Établissements sportifs couverts             F
#
#      etiquette_ges  annee_construction periode_construction  surface_shon  \
# 257            NaN                 NaN           avant 1948         104.7
# 1111             B              2005.0            2001-2005         283.4
#
#       surface_utile  nombre_occupant  \
# 257           100.0              0.0
# 1111          100.0              0.0
#
#                                           adresse_ban numero_voie_ban  \
# 257                    4 Rue du Château 18100 Vierzon               4
# 1111  9 Rue René Couzinet 95240 Cormeilles-en-Parisis               9
#
#             nom_rue_ban        nom_commune_ban  code_postal_ban  \
# 257      Rue du Château                Vierzon          18100.0
# 1111  Rue René Couzinet  Cormeilles-en-Parisis          95240.0
#
#      code_insee_ban code_departement_ban  code_region_ban   identifiant_ban  \
# 257           18279                   18             24.0  18279_0780_00004
# 1111          95176                   95             11.0  95176_0382_00009
#
#       coordonnee_cartographique_x_ban  coordonnee_cartographique_y_ban  \
# 257                         629717.22                       6680692.61
# 1111                        641515.31                       6873627.95
#
#       score_ban                  statut_geocodage          adresse_brut  \
# 257        0.56  adresse géocodée ban à l'adresse      4 rue du chateau
# 1111       0.56  adresse géocodée ban à l'adresse  9, rue René Couzinet
#
#                    nom_commune_brut  code_postal_brut  \
# 257                         VIERZON             18100
# 1111  CORMEILLES EN PARISIS, France             95240
#
#       numero_etage_appartement nom_residence complement_adresse_batiment  \
# 257                        0.0           NaN     2310022-GBA BERRY LOIRE
# 1111                       0.0           NaN          23-09-TRAVERS-1210
#
#      complement_adresse_logement  conso_kwhep_m2_an  \
# 257                          NaN                NaN
# 1111                         NaN              390.5
#
#       emission_ges_kg_co2_m2_an type_energie_principale_chauffage  \
# 257                         NaN                               NaN
# 1111                       10.9                               NaN
#
#      type_energie_n1         type_usage_energie_n1  conso_ep_energie_n1  \
# 257              NaN                           NaN                  NaN
# 1111     Électricité  périmètre de l'usage inconnu             121702.2
#
#       conso_ef_energie_n1  frais_annuel_energie_n1  \
# 257                   NaN                      NaN
# 1111              52914.0                  15349.0
#
#       annee_releve_conso_energie_n1 type_energie_n2 type_usage_energie_n2  \
# 257                             NaN             NaN                   NaN
# 1111                         2023.0             NaN                   NaN
#
#       conso_ep_energie_n2  conso_ef_energie_n2  frais_annuel_energie_n2  \
# 257                   NaN                  NaN                      NaN
# 1111                  NaN                  NaN                      NaN
#
#       annee_releve_conso_energie_n2 type_energie_n3 type_usage_energie_n3  \
# 257                             NaN             NaN                   NaN
# 1111                            NaN             NaN                   NaN
#
#       conso_ep_energie_n3  conso_ef_energie_n3  frais_annuel_energie_n3  \
# 257                   NaN                  NaN                      NaN
# 1111                  NaN                  NaN                      NaN
#
#       annee_releve_conso_energie_n3
# 257                             NaN
# 1111                            NaN

# %% [markdown]
# # EXPLO

# %%
# Avec numéro RNB
len(df_dpe[df_dpe.id_rnb.notna()])
# Out:
# 494

# %%
rnb_list = list(df_dpe.id_rnb.unique())

rnb_list.remove(np.nan)

df_temp = df[df.equip_rnb.isin(rnb_list)]

print("Equipement avec une liaison :", len(df_temp))

df_temp.equip_type_famille.value_counts()
# Out:
# Equipement avec une liaison : 200
# equip_type_famille
# Equipement d'activités de forme et de santé    95
# Salle ou terrain spécialisé                    52
# Salle multisports                              18
# Salle de combat                                10
# Bassin de natation                              8
# Bowling                                         5
# Court de tennis                                 5
# Salle non spécialisée                           3
# Structure Artificielle d'Escalade               1
# Equipement d'athlétisme                         1
# Pas de tir                                      1
# Boulodrome                                      1
# Name: count, dtype: int64

# %%
# Création de df_eco
df_eco = df_temp.merge(df_dpe, right_on="id_rnb", left_on="equip_rnb")

# Colonne a séléctionner
colonne = "conso_kwhep_m2_an"

# On enlève les valeures nulles
df_eco = df_eco[df_eco[colonne].notna()]
print("Avec consomation :")
print(len(df_eco))

# On enlèves les valeures faibles
df_eco = df_eco[df_eco[colonne] > 1]
print("Avec consomation :")
print(len(df_eco))

display(df_eco.sample(2))
# Out:
# Avec consomation :
# 150
# Avec consomation :
# 146
#        equip_numero inst_numero inst_enqu_date           inst_nom inst_siret  \
# 116  E004I773330010  I773330010     2025-03-31    DYNAMIC FITNESS        NaN
# 40   E001I315550388  I315550388     2025-03-31  AQUAVELO TOULOUSE        NaN
#
#             inst_adresse inst_cp  new_name new_code inst_part_type_filter  \
# 116  2 IMPASSE DE CHEROY   77140   Nemours    77333                   NaN
# 40      2 RUE DE LIBERTE   31000  Toulouse    31555                   NaN
#
#     inst_uai  inst_acc_handi_type inst_trans_type inst_obs inst_date_etat  \
# 116      NaN  ["Handicap moteur"]             NaN      NaN     2024-04-24
# 40       NaN                  NaN         ["Bus"]      NaN            NaN
#
#     inst_date_creation inst_hs_bool  epci_code dep_code         dep_nom  \
# 116         2016-03-23          NaN  200023240       77  Seine-et-Marne
# 40          2017-10-19          NaN  243100518       31   Haute-Garonne
#
#     reg_code        reg_nom            epci_nom code_bdv   lib_bdv arr_code  \
# 116       11  Île-de-France  CC Pays de Nemours    77333   Nemours      774
# 40        76      Occitanie  Toulouse Métropole    31555  Toulouse      313
#
#           arr_name dens_niveau                        dens_lib  \
# 116  Fontainebleau           2  Centres urbains intermédiaires
# 40        Toulouse           1          Grands centres urbains
#
#     dep_code_filled               aca_nom                  zrr_simp  \
# 116              77   Académie de Créteil  NC - Commune non classée
# 40               31  Académie de Toulouse  NC - Commune non classée
#
#                 equip_nom                      equip_type_name  \
# 116  SALLE DE MUSCULATION  Salle de musculation/cardiotraining
# 40    BASSIN D'AQUABIKING        Bassin d'exercices aquatiques
#
#      equip_coordonnees equip_prop_nom                 equip_prop_type  \
# 116  48.26023, 2.72072            NaN  Etablissement privé commercial
# 40   43.63118, 1.41295            NaN  Etablissement privé commercial
#
#     equip_propsec_type                 equip_gest_type equip_cogest_type  \
# 116                NaN  Etablissement privé commercial               NaN
# 40                 NaN  Etablissement privé commercial               NaN
#
#     equip_dsp equip_ouv_public_bool equip_erp_type equip_erp_cat  \
# 116     false                  true          ["X"]             4
# 40      false                   NaN            NaN           NaN
#
#     equip_homo_date equip_homo_periode equip_service_date  \
# 116             NaN                NaN               2011
# 40              NaN                NaN               2017
#
#     equip_service_periode equip_travaux_date equip_travaux_periode  \
# 116      A partir de 2005                NaN                   NaN
# 40       A partir de 2005                NaN                   NaN
#
#     equip_travaux_type equip_energie equip_nature  equip_sol equip_long  \
# 116                NaN           NaN    Intérieur    Parquet       14.0
# 40                 NaN           NaN    Intérieur  Carrelage        NaN
#
#     equip_larg equip_haut equip_surf equip_eclair equip_trib_nb  \
# 116       10.0        3.0      140.0         true             0
# 40         NaN        NaN        NaN         true             0
#
#     equip_vest_sport equip_vest_ens equip_douche equip_sanit  \
# 116                2              0         true        true
# 40               NaN            NaN         true        true
#
#                                         equip_loc_type equip_conf_type  \
# 116  ["Reception/accueil", "Bureau(x) club(s)", "Bu...       ["Sauna"]
# 40                            ["Reception", "accueil"]             NaN
#
#                             equip_acces_handi_mobilite  \
# 116  Accueil,Aire de jeu,Cheminements,Douches,Sanit...
# 40                                                 NaN
#
#     equip_acces_handi_sensoriel equip_pdesi_pdipr equip_bassin_long  \
# 116                  Sanitaires               NaN               NaN
# 40                          NaN               NaN               NaN
#
#     equip_bassin_larg equip_bassin_surf equip_bassin_min equip_bassin_max  \
# 116               NaN               NaN              NaN              NaN
# 40                NaN              45.0              NaN              NaN
#
#     equip_piste_long equip_sae_haut equip_sae_surf equip_sae_couloir  \
# 116              NaN            NaN            NaN               NaN
# 40               NaN            NaN            NaN               NaN
#
#     equip_pasdetir                     equip_url  \
# 116            NaN  http://www.dynamicfitness.fr
# 40             NaN                           NaN
#
#                                      equip_utilisateur equip_acc_libre  \
# 116  ["Individuel(s),famille(s)", "Clubs sportifs,c...           false
# 40                        ["Individuel(s),famille(s)"]           false
#
#     equip_saison                                          equip_obs  \
# 116        false                                                NaN
# 40         false  La piscine est chauffée entre 27 à 30°C toute ...
#
#                               equip_type_famille equip_type_code  \
# 116  Equipement d'activités de forme et de santé             802
# 40   Equipement d'activités de forme et de santé             803
#
#         equip_rnb inst_acc_handi_bool inst_trans_bool inst_part_bool  \
# 116  HH9MPAJC13B5                true           false          false
# 40   B45YK13WK6SZ               false            true          false
#
#     equip_loc_bool equip_pmr_vest equip_pmr_acc equip_pmr_aire equip_pmr_chem  \
# 116           true           true          true           true           true
# 40            true          false         false          false          false
#
#     equip_pmr_douche equip_pmr_sanit equip_pmr_trib equip_pshs_aire  \
# 116             true            true          false           false
# 40             false           false          false           false
#
#     equip_pshs_chem equip_pshs_sanit equip_pshs_sign equip_pshs_trib  \
# 116           false             true           false           false
# 40            false            false           false           false
#
#     equip_pshs_vest   equip_x  equip_y inst_part_type equip_qpv  \
# 116           false  48.26023  2.72072            NaN       NaN
# 40            false  43.63118  1.41295            NaN       NaN
#
#     equip_qpv_200m categorie     numero_dpe date_derniere_modification_dpe  \
# 116            NaN       NaN  2277T0996806H                     2024-12-30
# 40             NaN       NaN  2431T2010343U                     2024-12-30
#
#     date_visite_diagnostiqueur date_etablissement_dpe date_reception_dpe  \
# 116                 2022-04-18             2022-05-08         2022-05-09
# 40                  2024-06-02             2024-06-05         2024-06-05
#
#     date_fin_validite_dpe numero_dpe_remplace  numero_dpe_immeuble_associe  \
# 116            2032-05-07                 NaN                          NaN
# 40             2034-06-04                 NaN                          NaN
#
#            id_rnb provenance_id_rnb numero_immatriculation_copropriete  \
# 116  HH9MPAJC13B5       Reprise RNB                                NaN
# 40   B45YK13WK6SZ       Reprise RNB                                NaN
#
#                     modele_dpe  version_dpe            methode_dpe  \
# 116  DPE 2006 tertiaire et ERP          2.1  dpe tertiaire facture
# 40   DPE 2006 tertiaire et ERP          2.3  dpe tertiaire facture
#
#       categorie_erp                      secteur_activite etiquette_dpe  \
# 116  5ème Catégorie  X : Établissements sportifs couverts             D
# 40   5ème Catégorie  X : Établissements sportifs couverts             G
#
#     etiquette_ges  annee_construction periode_construction  surface_shon  \
# 116             D                 NaN            1978-1982        1098.8
# 40              C                 NaN            2013-2021         632.1
#
#      surface_utile  nombre_occupant                         adresse_ban  \
# 116          100.0            200.0   2 Impasse de Chéroy 77140 Nemours
# 40           100.0              0.0  2 Rue de l' Egalité 31200 Toulouse
#
#     numero_voie_ban        nom_rue_ban nom_commune_ban  code_postal_ban  \
# 116               2  Impasse de Chéroy         Nemours          77140.0
# 40                2  Rue de l' Egalité        Toulouse          31200.0
#
#     code_insee_ban code_departement_ban  code_region_ban   identifiant_ban  \
# 116          77333                   77             11.0  77333_0201_00002
# 40           31555                   31             76.0  31555_2906_00002
#
#      coordonnee_cartographique_x_ban  coordonnee_cartographique_y_ban  \
# 116                        679250.47                       6795608.78
# 40                         571785.07                       6282608.95
#
#      score_ban                  statut_geocodage  \
# 116       0.49  adresse géocodée ban à l'adresse
# 40        0.72  adresse géocodée ban à l'adresse
#
#                                adresse_brut nom_commune_brut  \
# 116  2 IMPASSE DE CHEROY\nZONE INDUSTRIELLE          NEMOURS
# 40                      2 Rue de l' Egalité         TOULOUSE
#
#      code_postal_brut  numero_etage_appartement nom_residence  \
# 116             77140                       0.0           NaN
# 40              31200                       0.0           NaN
#
#     complement_adresse_batiment complement_adresse_logement  \
# 116                         NaN                         NaN
# 40           2529-SCI DU POINTU                         NaN
#
#      conso_kwhep_m2_an  emission_ges_kg_co2_m2_an  \
# 116              215.6                       29.8
# 40               575.7                       16.0
#
#     type_energie_principale_chauffage type_energie_n1  \
# 116                               NaN     Gaz naturel
# 40                                NaN     Électricité
#
#             type_usage_energie_n1  conso_ep_energie_n1  conso_ef_energie_n1  \
# 116  périmètre de l'usage inconnu             144309.0             144309.0
# 40   périmètre de l'usage inconnu             400258.7             174025.5
#
#      frais_annuel_energie_n1  annee_releve_conso_energie_n1 type_energie_n2  \
# 116                  10380.0                         2021.0     Électricité
# 40                   26684.0                         2023.0             NaN
#
#             type_usage_energie_n2  conso_ep_energie_n2  conso_ef_energie_n2  \
# 116  périmètre de l'usage inconnu             116232.8              50536.0
# 40                            NaN                  NaN                  NaN
#
#      frais_annuel_energie_n2  annee_releve_conso_energie_n2 type_energie_n3  \
# 116                   9938.0                         2021.0             NaN
# 40                       NaN                            NaN             NaN
#
#     type_usage_energie_n3  conso_ep_energie_n3  conso_ef_energie_n3  \
# 116                   NaN                  NaN                  NaN
# 40                    NaN                  NaN                  NaN
#
#      frais_annuel_energie_n3  annee_releve_conso_energie_n3
# 116                      NaN                            NaN
# 40                       NaN                            NaN

# %% [markdown]
# # PREMIER GRAPH

# %%
# Petite boucle pour associer chaque type de bâtiment à un entier... c'est pas ouf mais ça marche
types = df_eco['equip_type_famille'].unique()
type_to_y = {t: i for i, t in enumerate(types)}
y_values = df_eco['equip_type_famille'].map(type_to_y)

# Tracer
plt.figure(figsize=(10, 6))
plt.scatter(df_eco[colonne], y_values, alpha=0.7)

# Customiser l'axe y avec les noms
plt.yticks(ticks=range(len(types)), labels=types)

plt.xlabel('Consommation ('+ colonne +')')
plt.xscale('log')

plt.title('Consommation par famille')
plt.tight_layout()

plt.show()

# %% [markdown]
# # GRAPH CLASSE

# %%
# Ordre perso pour voir un peu mieux à but d'export
ordre_personnalise = [
    'Court de tennis',
    'Salle non spécialisée',
    'Boulodrome',
    "Equipement d'athlétisme",
    'Pas de tir',
    "Structure Artificielle d'Escalade",
    'Salle de combat',
    'Salle multisports',
    'Salle ou terrain spécialisé',
    "Equipement d'activités de forme et de santé",
    'Bowling',
    'Bassin de natation'
]

# Associer chaque type de bâtiment à un entier comme au dessus
# Auparavent types = df_eco['equip_type_famille'].unique()
type_to_y = {t: i for i, t in enumerate(ordre_personnalise)}
y_values = df_eco['equip_type_famille'].map(type_to_y)

# Tracer
plt.figure(figsize=(10, 6))
plt.scatter(df_eco[colonne], y_values, alpha=0.7)

# Customiser l'axe y avec les noms
plt.yticks(ticks=range(len(ordre_personnalise)), labels=ordre_personnalise)

plt.xlabel('Consommation ('+ colonne +')')
#plt.xscale('log')

plt.title('Consommation par famille')
plt.tight_layout()

plt.show()
